# %%
# Out:
# {
#     "estado": {
#         "text": "AUTORIZADO"
#     },
#     "numeroAutorizacion": {
#         "text": "1811202401179285143200120010030000130430001304313"
#     },
#     "fechaAutorizacion": {
#         "text": "2024-11-18T09:31:41-05:00"
#     },
#     "ambiente": {
#         "text": "PRODUCCI\u00c3\u201cN"
#     },
#     "comprobante": {
#         "id": "comprobante",
#         "version": "2.1.0",
#         "infoTributaria": {
#             "ambiente": {
#                 "text": "2"
#             },
#             "tipoEmision": {
#                 "text": "1"
#             },
#             "razonSocial": {
#                 "text": "Asoc De Cuentas En Part Luis Leonardo Tito Velastegui Procar"
#             },
#             "nombreComercial": {
#                 "text": "Procar"
#             },
#             "ruc": {
#                 "text": "1792851432001"
#             },
#             "claveAcceso": {
# ...
